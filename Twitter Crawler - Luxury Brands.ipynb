# %%
from twython import Twython

# %%
TWITTER_APP_KEY = 'hxDqMPLDWZ8a88k5mYhmtsz6x' #supply the appropriate value
TWITTER_APP_KEY_SECRET = 'CFzapvfi6Ilj8mSceF4Vvz36dV0W8EXlvdLK0xkOf4uipcQawi' 
TWITTER_ACCESS_TOKEN = '877605709348777984-ZBreHfCgWZDqoUgWgY2YcAKuFDwMuCx'
TWITTER_ACCESS_TOKEN_SECRET = '6nSaAVQrfwKoTTTogLANZKaow0edidEtv9vn4PZqEdYpQ'

t = Twython(app_key=TWITTER_APP_KEY, 
            app_secret=TWITTER_APP_KEY_SECRET, 
            oauth_token=TWITTER_ACCESS_TOKEN, 
            oauth_token_secret=TWITTER_ACCESS_TOKEN_SECRET)

search = t.search(q='#Coach',   #**supply whatever query you want here**
                  count=200)

tweets = search['statuses']

for tweet in tweets:
  print tweet['id_str'], '\n', tweet['text'], '\n\n\n'
# Out:
# 877931962534567936
# People only work like a team when someone leads like a coach! #MooreThoughts #leadership #coach… https://t.co/1FjWdKyNcc
#
#
#
# 877931779088199680
# RT @coachestribune: Simple game!  No shortcuts!  #truth #sports #youthsports #motivation #coach #coaching #coachestribune 🔥🔥🔥 https://t.co/…
#
#
#
# 877931687858065408
# RT @stancareerblog: Find a Summer Job Now!
#  https://t.co/6XajJfDk7P
# #jobs #coach #success #jobsearch #jobsearch #summerjob #summerjobs #su…
#
#
#
# 877930904324386816
# #watch #truth #life #coach #car #vehicle #no #worries #faith #mission #people #god #favor… https://t.co/OKtxhu9wQN
#
#
#
# 877930511896674304
# Find a Summer Job Now!
#  https://t.co/6XajJfDk7P
# #jobs #coach #success #jobsearch #jobsearch #summerjob #summerjobs #summer-camp-jobs
#
#
#
# 877929601955094528
# #Bags #Authentic #Coach Tote #Bag #HandBag F16538 PENELOPE Signature Logo Jacquard GUC https://t.co/GxZ6zwmID3… https://t.co/6h5JZWiLp3
#
#
#
# 877929586733928449
# ...

# %%
TWITTER_APP_KEY = 'hxDqMPLDWZ8a88k5mYhmtsz6x' #supply the appropriate value
TWITTER_APP_KEY_SECRET = 'CFzapvfi6Ilj8mSceF4Vvz36dV0W8EXlvdLK0xkOf4uipcQawi' 
TWITTER_ACCESS_TOKEN = '877605709348777984-ZBreHfCgWZDqoUgWgY2YcAKuFDwMuCx'
TWITTER_ACCESS_TOKEN_SECRET = '6nSaAVQrfwKoTTTogLANZKaow0edidEtv9vn4PZqEdYpQ'

t = Twython(app_key=TWITTER_APP_KEY, 
            app_secret=TWITTER_APP_KEY_SECRET, 
            oauth_token=TWITTER_ACCESS_TOKEN, 
            oauth_token_secret=TWITTER_ACCESS_TOKEN_SECRET)

search = t.search(q='#MichaelKors',   #**supply whatever query you want here**
                  count=200)

tweets = search['statuses']

for tweet in tweets:
  print tweet['id_str'], '\n', tweet['text'], '\n\n\n'
# Out:
# 877931236575944705
# #Buzz #Bag: #MichaelKors #Purse and belt https://t.co/ZqIk03oDal #Quality https://t.co/oeVuLcFAND
#
#
#
# 877931231517712385
# #Hot #MichaelKors Jet Set E/W Signature Tote Beige/Ebony/Vaccetta New with Tags https://t.co/dUgh50uVRS #Bag #Style https://t.co/coKWG3BsN7
#
#
#
# 877929986434281472
# #Frugaldivastyle #youtuber #nyc #bathandbodyworkscandles #lushuk #lushkitchen #michaelkors… https://t.co/aLNz8te7H0
#
#
#
# 877922640001880065
# RT @whitehousedress: #FLOTUS in gorgeous shirt dress with what looks like #MichaelKors belt &amp; #ChristianLouboutin flats. https://t.co/mFBrG…
#
#
#
# 877919671655186433
# MK crossbody for $55! Call to purchase 610-524-6000 #pcexton #michaelkors #designer https://t.co/DToVt0FGvp
#
#
#
# 877919555716239360
# El vestido que causó sensación en la reunión de Trump y los Gobernantes de Panamá https://t.co/08uhf9FSSq #tbt #moda #fashion #michaelkors
#
#
#
# 877918447732047872
# ...

# %%
TWITTER_APP_KEY = 'hxDqMPLDWZ8a88k5mYhmtsz6x' #supply the appropriate value
TWITTER_APP_KEY_SECRET = 'CFzapvfi6Ilj8mSceF4Vvz36dV0W8EXlvdLK0xkOf4uipcQawi' 
TWITTER_ACCESS_TOKEN = '877605709348777984-ZBreHfCgWZDqoUgWgY2YcAKuFDwMuCx'
TWITTER_ACCESS_TOKEN_SECRET = '6nSaAVQrfwKoTTTogLANZKaow0edidEtv9vn4PZqEdYpQ'

t = Twython(app_key=TWITTER_APP_KEY, 
            app_secret=TWITTER_APP_KEY_SECRET, 
            oauth_token=TWITTER_ACCESS_TOKEN, 
            oauth_token_secret=TWITTER_ACCESS_TOKEN_SECRET)

search = t.search(q='#Chanel',   #**supply whatever query you want here**
                  count=200)

tweets = search['statuses']

for tweet in tweets:
  print tweet['id_str'], '\n', tweet['text'], '\n\n\n'
# Out:
# 877932755857715200
# RT @YGInstagram: [VIDEO] W Korea's IG Update of G-Dragon.
# "G-Dragon performed live at a #Chanel #Mademoiselle Prive afterparty tonight." h…
#
#
#
# 877932239593455616
# [Fashion]#CL Coat：#CHANEL Cashmere Coat $6521 https://t.co/w6zbO62eZx  cr : clswardrobe
#
#
#
# 877932125936205824
# [Fashion]#CL Bag：#CHANEL Rocket Minaudiere Bag https://t.co/KfvDDwvUUq cr :clswardrobe
#
#
#
# 877932110199128064
# RT @HanAnooY: Looking so freaking goooood 🔥🔥🔥 #YoonA #Chanel #MademoisellePrive https://t.co/efuhy0KW0b
#
#
#
# 877931517028126720
# RT @kouzaisaki: 最近はこの2つの香水をmixして使うのがマイブームですฅ(^ •ω•*^ฅ♡
# BAさんに教えて頂いたの。
#
#  #perfumes
#  #お気に入りの香水
#  #chanel
#  #chance… https://t.co/JD4L3a91fc
#
#
#
# 877931511646887936
# RT @lizahasanova: [170621] #GDRAGON at #Chanel after party S-Factory club (cr. yoooooonjin) https://t.co/F8gJJ8MIdV
#
#
#
# 877931394525085696
# ...

# %%
TWITTER_APP_KEY = 'hxDqMPLDWZ8a88k5mYhmtsz6x' #supply the appropriate value
TWITTER_APP_KEY_SECRET = 'CFzapvfi6Ilj8mSceF4Vvz36dV0W8EXlvdLK0xkOf4uipcQawi' 
TWITTER_ACCESS_TOKEN = '877605709348777984-ZBreHfCgWZDqoUgWgY2YcAKuFDwMuCx'
TWITTER_ACCESS_TOKEN_SECRET = '6nSaAVQrfwKoTTTogLANZKaow0edidEtv9vn4PZqEdYpQ'

t = Twython(app_key=TWITTER_APP_KEY, 
            app_secret=TWITTER_APP_KEY_SECRET, 
            oauth_token=TWITTER_ACCESS_TOKEN, 
            oauth_token_secret=TWITTER_ACCESS_TOKEN_SECRET)

search = t.search(q='#Gucci',   #**supply whatever query you want here**
                  count=200)

tweets = search['statuses']

for tweet in tweets:
  print tweet['id_str'], '\n', tweet['text'], '\n\n\n'
# Out:
# 877931237641404416
# #Gucci #Belt Authentic Red Gucci GG Belt https://t.co/HvJbzmSGkp #Fashion #Style https://t.co/ndu0t4qJ6i
#
#
#
# 877931227398799360
# #Gucci #Fashion: Vintage GUCCI - Black Guccissma Canvas Jacard Fabric With GG Logo Tote Handbag… https://t.co/tQGXShLbEc
#
#
#
# 877930750510870528
# RT @Poshmarkapp: BUY Gucci at prices you won't believe! Install the free app and shop now! #gucci https://t.co/x87mrdpJ7D
#
#
#
# 877930725797920770
# #mode #GUCCI Polo gucci a col bande et abeille neuf XXL https://t.co/TNdI7Ruyv1 #fashion
#
#
#
# 877930703433891841
# #Repost @therealdvice (@get_repost)
# ・・・
# 👁 Ya Puedes Buscar el video de #GUCCI👻 en @YouTube 🏌🏻🏌🏻🏌🏻🏌🏻🏌🏻... https://t.co/u2SgEFIPbH
#
#
#
# 877930691203223552
# RT @lindsaylohan: #gucci #balmain #truefriends #nicegirls  😍😎😇 https://t.co/HEMSGOgx8V
#
#
#
# 877929768708055040
# #whatiwantmost gucci messenger bag/brown monogram with signature green… https://t.co/pEDH8cuoEw #boutique #fashion #gucci #handbags #forsale
#
#
# ...

# %%
TWITTER_APP_KEY = 'hxDqMPLDWZ8a88k5mYhmtsz6x' #supply the appropriate value
TWITTER_APP_KEY_SECRET = 'CFzapvfi6Ilj8mSceF4Vvz36dV0W8EXlvdLK0xkOf4uipcQawi' 
TWITTER_ACCESS_TOKEN = '877605709348777984-ZBreHfCgWZDqoUgWgY2YcAKuFDwMuCx'
TWITTER_ACCESS_TOKEN_SECRET = '6nSaAVQrfwKoTTTogLANZKaow0edidEtv9vn4PZqEdYpQ'

t = Twython(app_key=TWITTER_APP_KEY, 
            app_secret=TWITTER_APP_KEY_SECRET, 
            oauth_token=TWITTER_ACCESS_TOKEN, 
            oauth_token_secret=TWITTER_ACCESS_TOKEN_SECRET)

search = t.search(q='#Hermès',   #**supply whatever query you want here**
                  count=200)

tweets = search['statuses']

for tweet in tweets:
  print tweet['id_str'], '\n', tweet['text'], '\n\n\n'
# Out:
# 877932547648376832
# RT @BTS_twt: #wanderland
# #파리지앵의산책
# #디뮤지엄
# #Hermes https://t.co/7ct8wj0n3v
#
#
#
# 877931730421809154
# Make your #handbag dreams come true by investing in this authentic #Hermes Birkin bag https://t.co/yeQTBopaUQ https://t.co/bb9NRJji7l
#
#
#
# 877931234327797760
# #Luxury #Bags #Hermes 35cm Blue &amp; White Clemence Leather Birkin #Bag Palladium Hardware https://t.co/H4QYgrSSat… https://t.co/67TwrU04a1
#
#
#
# 877931222940344320
# #Fashion #Plus: #Hermes Poudre Box Leather Sellier Kelly 25cm Gold Hardware https://t.co/akwmpHwm6h #Bag https://t.co/W0aPPPKOXQ
#
#
#
# 877930486600880128
# [Amazon]エルメス HERMES 李氏の庭 EDT SP 100ml オードトワレ スプレー 売り切り必死の大人気フレグランスが大特価で★　https://t.co/6vRlYamzfN
# #Amazon #女子力 #エルメス ＃hermes #李氏の庭
#
#
#
# 877929837280845824
# RT @SuesMoore: #Bags #Deal: #Hermes 35cm Blue &amp; White Clemence Leather Birkin #Bag Palladium Hardware https://t.co/T12svLh1Xu #HandBag http…
#
#
#
# 877929615255191552
# ...

# %%
TWITTER_APP_KEY = 'hxDqMPLDWZ8a88k5mYhmtsz6x' #supply the appropriate value
TWITTER_APP_KEY_SECRET = 'CFzapvfi6Ilj8mSceF4Vvz36dV0W8EXlvdLK0xkOf4uipcQawi' 
TWITTER_ACCESS_TOKEN = '877605709348777984-ZBreHfCgWZDqoUgWgY2YcAKuFDwMuCx'
TWITTER_ACCESS_TOKEN_SECRET = '6nSaAVQrfwKoTTTogLANZKaow0edidEtv9vn4PZqEdYpQ'

t = Twython(app_key=TWITTER_APP_KEY, 
            app_secret=TWITTER_APP_KEY_SECRET, 
            oauth_token=TWITTER_ACCESS_TOKEN, 
            oauth_token_secret=TWITTER_ACCESS_TOKEN_SECRET)

search = t.search(q='#LouisVuitton',   #**supply whatever query you want here**
                  count=200)

tweets = search['statuses']

for tweet in tweets:
  print tweet['id_str'], '\n', tweet['text'], '\n\n\n'
# Out:
# 877933013689974784
# รูปน้องโจว จาก gettyimages อีกเพียบเลย ไปเก็บกันได้
# https://t.co/tLSasoXOy2
# #weizhou #TimmyXu #LouisVuitton… https://t.co/ldq7ym2LSU
#
#
#
# 877932723087659008
# RT @LouisVuitton: For the #LVMenSS18 show @Drake will be premiering a song inspired by the #LouisVuitton collection by @mrkimjones. Tomorro…
#
#
#
# 877932678313586689
# RT @ConroyC: Drake always delivers #Signs #LouisVuitton 💯💯💯
#
#
#
# 877932566619324418
# RT @LouisVuitton: The #LouisVuitton #LVMenSS18 Show by @MrKimJones will be live from #PFW today, 2:30pm Paris Time at https://t.co/Je7xaeI2…
#
#
#
# 877932435014430720
# #mode Divers Louis Vuitton https://t.co/O2lKPPs2xP #LouisVuitton
#
#
#
# 877932408909312000
# @Drake #OVOSOUNDRADIO Episode #NEW 46 TOMORROW 5pm PST / 8PM EST / 12AM GMT #LouisVuitton #HHLMNEWS #HHLM… https://t.co/p4OUWB19CW
#
#
#
# 877932286313766912
# RT @LouisVuitton: The #LouisVuitton #LVMenSS18 Show by @mrkimjones live from the Palais Royal in Paris, France
# ...

# %%
TWITTER_APP_KEY = 'hxDqMPLDWZ8a88k5mYhmtsz6x' #supply the appropriate value
TWITTER_APP_KEY_SECRET = 'CFzapvfi6Ilj8mSceF4Vvz36dV0W8EXlvdLK0xkOf4uipcQawi' 
TWITTER_ACCESS_TOKEN = '877605709348777984-ZBreHfCgWZDqoUgWgY2YcAKuFDwMuCx'
TWITTER_ACCESS_TOKEN_SECRET = '6nSaAVQrfwKoTTTogLANZKaow0edidEtv9vn4PZqEdYpQ'

t = Twython(app_key=TWITTER_APP_KEY, 
            app_secret=TWITTER_APP_KEY_SECRET, 
            oauth_token=TWITTER_ACCESS_TOKEN, 
            oauth_token_secret=TWITTER_ACCESS_TOKEN_SECRET)

search = t.search(q='#Prada',   #**supply whatever query you want here**
                  count=200)

tweets = search['statuses']

for tweet in tweets:
  print tweet['id_str'], '\n', tweet['text'], '\n\n\n'
# Out:
# 877933160922660866
# RT @A_Calascibetta: Se l'imperfezione diventa perfezione @Prada #Prada @StyleMagazineIt #mfwss18 #mfw #mensfashion #ss18 https://t.co/GBNqA…
#
#
#
# 877932483609624576
# #Prada #Handbags: Prada Saffiano Lux Leather Tote in Sabbia Pristine BN1844 https://t.co/T8sW9pXFQw #Handbag https://t.co/Dw6NSD4N1O
#
#
#
# 877931243601444864
# #Fashion #Style: #Prada BR1845 Black Pebbled Leather Semitracolla Vit Daino Shoulder #HandBag #Bag… https://t.co/EeLk5UJeuP
#
#
#
# 877930020408360960
# It's too hot for anything , and I give up #ootd #lanvin #shirt #topman #shorts #prada #shoes… https://t.co/jGdS38qeVT
#
#
#
# 877929409503666176
# Retweet your Favarite！ https://t.co/DbEondR2O9  #katespade　#prada #samantha #chloe #loewe #coach https://t.co/2LDhnELSP6
#
#
#
# 877926961112162304
# #Fashion #Style: #Authentic #Prada EUC #Bag in bluette https://t.co/MLI00th2TF https://t.co/ib4JXphF1D
#
#
#
# 877926888429174784
# ...

# %%
TWITTER_APP_KEY = 'hV9lFp0oep1VZZ127ezyyDSec' #supply the appropriate value
TWITTER_APP_KEY_SECRET = 'ffh98fjuMh4PbfuVNyFiwUAjHav0HsTxtRX110oxgM4Tj0WnJ6'
TWITTER_ACCESS_TOKEN = '877605709348777984-ZBreHfCgWZDqoUgWgY2YcAKuFDwMuCx'
TWITTER_ACCESS_TOKEN_SECRET = '6nSaAVQrfwKoTTTogLANZKaow0edidEtv9vn4PZqEdYpQ'

t = Twython(app_key=TWITTER_APP_KEY, 
            app_secret=TWITTER_APP_KEY_SECRET, 
            oauth_token=TWITTER_ACCESS_TOKEN, 
            oauth_token_secret=TWITTER_ACCESS_TOKEN_SECRET)

search = t.search(q='#Mouawad',   #**supply whatever query you want here**
                  count=200)

tweets = search['statuses']

for tweet in tweets:
  print tweet['id_str'], '\n', tweet['text'], '\n\n\n'
# Out:
# 877911055996813312
# «Nessuno mi ha avvertito, nessuno si è preoccupato di domandarmi se andava tutto bene, così oggi mi sento un po' pe… https://t.co/px8gJTnEeI
#
#
#
# 877594475035410432
# Mouawad's exquisite Royale Rings elevate a classic style with a unique center stone. #Mouawad #Mouaw... [Mouawad] https://t.co/vDkwvOwxxD
#
#
#
# 877520215382163456
# RT @mouawadjewelry: Mouawad's exquisite Royale Rings elevate a classic style with a unique center stone. #Mouawad #MouawadMoment https://t.…
#
#
#
# 877520023828316160
# Mouawad's exquisite Royale Rings elevate a classic style with a unique center stone. #Mouawad #MouawadMoment… https://t.co/IHFu53sO20
#
#
#
# 877415441202851840
# RT @mouawadjewelry: Indulge yourself in the warmth of red #rubies nestled among white #diamonds in this exquisite suite by #Mouawad. https:…
#
#
#
# 877415350492688385
# ...

# %%
TWITTER_APP_KEY = 'hV9lFp0oep1VZZ127ezyyDSec' #supply the appropriate value
TWITTER_APP_KEY_SECRET = 'ffh98fjuMh4PbfuVNyFiwUAjHav0HsTxtRX110oxgM4Tj0WnJ6'
TWITTER_ACCESS_TOKEN = '877605709348777984-ZBreHfCgWZDqoUgWgY2YcAKuFDwMuCx'
TWITTER_ACCESS_TOKEN_SECRET = '6nSaAVQrfwKoTTTogLANZKaow0edidEtv9vn4PZqEdYpQ'

t = Twython(app_key=TWITTER_APP_KEY, 
            app_secret=TWITTER_APP_KEY_SECRET, 
            oauth_token=TWITTER_ACCESS_TOKEN, 
            oauth_token_secret=TWITTER_ACCESS_TOKEN_SECRET)

search = t.search(q='#KateSpade',   #**supply whatever query you want here**
                  count=200)

tweets = search['statuses']

for tweet in tweets:
  print tweet['id_str'], '\n', tweet['text'], '\n\n\n'
# Out:
# 877934228083789824
# kate spade black bow heels size 9.5 | eBay #katespade #bowheels
# https://t.co/WO2ROmYCd6 https://t.co/COuxt3Q3kJ
#
#
#
# 877932156906897408
# Love #katespade? Love #WHBM? Well right now when you spend $150 at WHBM, get a free kate spade wallet or $35 off yo… https://t.co/JUMXwrXV05
#
#
#
# 877929409503666176
# Retweet your Favarite！ https://t.co/DbEondR2O9  #katespade　#prada #samantha #chloe #loewe #coach https://t.co/2LDhnELSP6
#
#
#
# 877923150733783040
# RT @Whatabuy1961: Check out KATE SPADE New York Green Silk Cashmere Blend Cardigan Size XS #KateSpade #Cardigan https://t.co/cm2i6LGW40 via…
#
#
#
# 877922138199601153
# What's In My Bag https://t.co/H1B4itar9A #lbloggers @FemaleBloggerRT @BBlogRT @LovingBlogs @TheGirlGangHQ #katespade https://t.co/bEHR8NBCzj
#
#
#
# 877921849895567360
# Magical beautiful Change! ☆彡 with https://t.co/DbEondR2O9  　#katespade　#prada #samantha #chloe #loewe #coach https://t.co/FupdeJRTWV
#
#
#
# 877921362144145411
# ...

# %%
TWITTER_APP_KEY = 'hV9lFp0oep1VZZ127ezyyDSec' #supply the appropriate value
TWITTER_APP_KEY_SECRET = 'ffh98fjuMh4PbfuVNyFiwUAjHav0HsTxtRX110oxgM4Tj0WnJ6'
TWITTER_ACCESS_TOKEN = '877605709348777984-ZBreHfCgWZDqoUgWgY2YcAKuFDwMuCx'
TWITTER_ACCESS_TOKEN_SECRET = '6nSaAVQrfwKoTTTogLANZKaow0edidEtv9vn4PZqEdYpQ'

t = Twython(app_key=TWITTER_APP_KEY, 
            app_secret=TWITTER_APP_KEY_SECRET, 
            oauth_token=TWITTER_ACCESS_TOKEN, 
            oauth_token_secret=TWITTER_ACCESS_TOKEN_SECRET)

search = t.search(q='#Burberry',   #**supply whatever query you want here**
                  count=200)

tweets = search['statuses']

for tweet in tweets:
  print tweet['id_str'], '\n', tweet['text'], '\n\n\n'
# Out:
# 877937779786764288
# #Buzz #Burberry BUCKLE DETAIL LEATHER AND HOUSE CHECK CROSSBODY#Bag BLACK https://t.co/woiNb6w0pB #Style https://t.co/e8MdcT88C0
#
#
#
# 877937768378191872
# #Best #Bag #Burberry CROSSBODY #Bags BLUE NOVA CHECK https://t.co/YvVCfuw6CF #HandBag https://t.co/nkkHnmjUwO
#
#
#
# 877936784973287424
# An intense &amp; sensual #fragrance launched by #Burberry in 2016~
# (c): @YFSEricaNicole
# #luxury #perfume… https://t.co/z1Wik4d9nO
#
#
#
# 877933489005383680
# #Best #Bag #Burberry Canterbury Horseferry Check Tote #Bags https://t.co/8jJSFE8sJX #HandBag https://t.co/Fva2cbAjfK
#
#
#
# 877933479811469312
# #Buzz #Burberry Canterbury Horseferry Check Tote #Bag https://t.co/S0HjHEvmZM #Style https://t.co/LzD73ihtTi
#
#
#
# 877929499513413633
# #Best #Bag #Burberry Vintage Beige Nova Check Pattern Coated Canvas Leather Trim Tote B3989 https://t.co/Lu8kblRYcD… https://t.co/ZWu7D11RJH
#
#
#
# 877929496300498944
# ...
